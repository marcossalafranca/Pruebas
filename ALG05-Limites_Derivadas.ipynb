# %% [markdown]
# <img src="images/keepcoding.png" width=200 align="left">

# %% [markdown]
# <img src="images/me.jpg" width=150 align="right">
#
# # Funciones reales: límites y derivadas
#
# Autor: Carlos Moreno Morera
#
# Contacto: carlos.moreno@ibm.com
#
# Última revisión: 13/Jul/2022

# %% [markdown]
# ## 1.- Función real
#
# ### 1.1.- Definición
#
# Sea $C$ un conjunto, en teoría de conjuntos se denota por $C^2$ al producto cartesiano de $C$ consigo mismo, es decir, a $C\times C$. También se utiliza la notación $C^3$ como $C\times C\times C$, $C^4$ como $C\times C\times C\times C$ y así sucesivamente. Por lo tanto, cuando se utiliza la notación $C^n$ con $n\in\mathbb{N}$, se hace referencia a un conjunto al que se le ha aplicado el producto cartesiano consigo mismo $n$ veces.
#
# Una función real, es una función $f:\mathbb{R}^n\rightarrow\mathbb{R}^m$ cuyo dominio es un conjunto cuyos elementos son números reales (o tuplas de números reales) y su codominio igual. Veamos algunos ejemplos:
# - $f_1:\mathbb{R}^2\rightarrow\mathbb{R}$ tal que $f_1(x,y)=x+y$
# - $f_2:\mathbb{R}^3\rightarrow\mathbb{R}^5$ tal que $f_2(x, y, z) = (x + y, \frac{x^2 - y}{z}, z^y, 2^{x+y}, z)$
# - $f_3:\mathbb{R}\rightarrow\mathbb{R}$ tal que $f_3(x) = \pi^x$

# %%
#Implementamos las funciones
# Out:
# 8.4
# (-4.281718171540955, 1.8447507819141857, 5.69295539620604e-07, 0.05141317180482749, 7.8)
# 5.047497267370911

# %% [markdown]
# Los **intervalos** son los conjuntos básicos de la recta real $\mathbb{R}$, pudiendo ser abiertos o cerrados (según entren  no sus extremos) y acotados o infinitos:
# - Cerrado: $[a, b]=\{x\in\mathbb{R}:a\leq x\leq b\}$
# - Abierto: $(a, b)=\{x\in\mathbb{R}:a< x< b\}$
# - Semiabierto o semicerrado: $(a, b]=\{x\in\mathbb{R}:a< x\leq b\}$
# - Semiabierto o semicerrado: $[a, b)=\{x\in\mathbb{R}:a\leq x< b\}$
# - Infinito cerrado: $[a, \infty)=\{x\in\mathbb{R}:a\leq x\}$
# - Infinito abierto: $(a, \infty)=\{x\in\mathbb{R}:a< x\}$
# - Infinito cerrado: $(-\infty, a]=\{x\in\mathbb{R}:a\geq x\}$
# - Infinito abierto: $(-\infty, a)=\{x\in\mathbb{R}:a> x\}$
#
# ### 1.2.- Crecimiento y decrecimiento
# Se dice que una función real $f:\mathbb{R}\rightarrow\mathbb{R}$ es:
# - Creciente en el intervalo $I$, si $\forall x_1, x_2\in I$ con $x_1<x_2$ se cumple que $f(x_1)<f(x_2)$
# - Decreciente en el intervalo $I$, si $\forall x_1, x_2\in I$ con $x_1<x_2$ se cumple que $f(x_1)>f(x_2)$
# - Constante en el intervalo $I$, si $\forall x_1, x_2\in I$ se cumple que $f(x_1)=f(x_2)$
#
# Aunque en Python no podemos comprobar todos los valores de un intervalo (por haber infinitos número reales), si podemos coger una muestra

# %%
#Comprobemos si la función f(x) = x**2 es creciente en el intervalo [1, 5]
# Out:
# True
# False

# %% [markdown]
# ### 1.3.- Visualización de funciones
# En Python podemos visualizar las funciones:

# %%
#Visualizamos x**2

# %% [markdown]
# ## 2.- Matemáticas en Python
# ### 2.1.- Suposiciones en Sympy
# Sympy es una librería de Python utilizada para matemática simbólica. Para definir variables, esta librería cuenta con el objeto `Symbol`:
# > x=Symbol('x')
#
# Veamos un ejemplo:

# %%
#Supongamos que queremos chequear si x + 5 > 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-2af2952f2d8c> in <module>
#       2 from sympy import Symbol
#       3 x=Symbol('x')
# ----> 4 if (x+5)>0:
#       5     print('Ok')
#       6 else:
#
# ~\anaconda3\lib\site-packages\sympy\core\relational.py in __bool__(self)
#     396
#     397     def __bool__(self):
# --> 398         raise TypeError("cannot determine truth value of Relational")
#     399
#     400     def _eval_as_set(self):
#
# TypeError: cannot determine truth value of Relational

# %% [markdown]
# Como Sympy no sabe nada acerca del signo de **x**, no puede deducir si x+5 es mayor que 0, por lo que devuelve un error.

# %%
# Out:
# Ok

# %% [markdown]
# ¿Y si lo deifiniésemos con signo negativo?

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-56386fe54907> in <module>
#       1 from sympy import Symbol
#       2 x=Symbol('x',negative=True)
# ----> 3 if (x+5)>0:
#       4     print('Ok')
#       5 else:
#
# ~\anaconda3\lib\site-packages\sympy\core\relational.py in __bool__(self)
#     396
#     397     def __bool__(self):
# --> 398         raise TypeError("cannot determine truth value of Relational")
#     399
#     400     def _eval_as_set(self):
#
# TypeError: cannot determine truth value of Relational

# %% [markdown]
# Además de poder declarar un *symbol* como positivo y negativo, también es posible especificar si es real, integer, complex, imaginary, y muchio más.
# Estas declaraciones es lo que se llama **suposiciones en Sympy**.
#
# ## 3.- Límites
#
# Algo común en cálculo es calcular el valor al que se aproxima una función.
#
# Ejemplo: Consideremos la función $\frac{1}{x}$
#
# <img src="Images/main-qimg-c5be56e1b5d297b9995615a47707f52b.png" style="width: 400px;"/>
#
# Queremos calcular $\lim_{x \to \infty}(\frac{1}{x})$

# %%
# Out:
# Limit(1/x, x, oo, dir='-')

# %%
# Out:
# 0

# %% [markdown]
# Por defecto, Limit toma la dirección positiva. Si queremos calcular $\lim_{x \to -\infty}(\frac{1}{x})$:

# %%
# Out:
# 0

# %% [markdown]
# Queremos calcular $\lim_{x \to 0}(\frac{1}{x})$

# %%
# Out:
# oo

# %%
# Out:
# -oo

# %% [markdown]
# Limit soporta también indeterminaciones del tipo 0/0 y $\infty$/$\infty$
#
# Queremos calcular $\lim_{x \to 0}(\frac{senx}{x})$

# %%
# Out:
# 1

# %% [markdown]
# No podíamos pasar de largo hablar del término $(1+\frac{1}{n})^{n}$, quien Bernoulli demostró que tendía a *e*

# %%
# Out:
# E

# %% [markdown]
# ## 4.- Derivadas
#
# ### 4.1.- Definición y ejemplos
#
# Comencemos con un ejemplo inicial:
# Consideremos un coche que acelera uniformemente, cuya ecuación de velocidad viene dada por:
# > S(t)=5t<sup>2</sup>+2t+8
#
# En esta función, la variable independiente es *t*, que representa el tiempo transcurrido desde que el coche empezó a moverse.
# Si medimos la distancia recorrida entre los tiempos t<sub>1</sub> y t<sub>2</sub>, con t<sub>2</sub>>t<sub>1</sub>, podemos calcular la distancia que se mueve en coche en una unidad de tiempo:
#
# > $\frac{S(t_{2})-S(t_{1})}{t_{2}-t_{1}}$
#
# Esto también se conoce como la tasa promedio de cambio de la función S con respecto a la variable t, o en otras palabras, la velocidad promedio.
# Si escribimos t<sub>2</sub> como t<sub>1</sub>+$\delta_{t}$, donde $\delta_{t}$ es la diferencia entre t<sub>2</sub> y t<sub>1</sub>, podemos reescribir la expresión para la velocidad media como
#
# > $\frac{S(t_{1}+\delta_{t})-S(t_{1})}{\delta_{t}}$
#
# Supongamos que $\delta_{t}$ es lo suficientemente pequeño (conseguiríamos calcular la velocidad en un punto):
#
# > $lim_{{\delta_{t}} \to 0} {\frac{S(t_{1}+\delta_{t})-S(t_{1})}{\delta_{t}}}$

# %%
# Out:
# 10*t1 + 2

# %% [markdown]
# Esto también se conoce como **velocidad instantánea**. Además, este límite se conoce como la **derivada de una función**.
#
# > f'(t)=$lim_{{\delta_{t}} \to 0} {\frac{S(t_{1}+\delta_{t})-S(t_{1})}{\delta_{t}}}$
#
# Muchos recordaréis la famosa tabla de derivadas que estudiábamos en el colegio:
#
# <img src="Images/tabla-derivadas2.jpg" style="width: 500px;"/>
#
# Por suerte, ahora no nos va a hacer falta, ya que disponemos en sympy de la función *Derivative*
#
# Ejemplo:
# Vamos a derivar la función S(t)=5t<sup>2</sup>+2t+8
#
# <img src="Images/f1.png" style="width: 500px;"/>

# %%
# Out:
# 10*t + 2

# %% [markdown]
# Si queremos evaluar la derivada en un valor determinado, usaremos *subs()*.
#
# Ejemplo:
# Vamos a derivar la función S(t)=5t<sup>2</sup>+2t+8 en t=1

# %%
# Out:
# 12

# %% [markdown]
# Ejemplo:
# Vamos a derivar la función (x<sup>3</sup>-x<sup>2</sup>+x)+(x<sup>2</sup>+x)

# %%
# Out:
# (2*x + 1)*(x**3 + x**2 + x) + (x**2 + x)*(3*x**2 + 2*x + 1)

# %% [markdown]
# ### 4.2.- Máximos y mínimos
#
# Los máximos y los mínimos relativos de una función son aquellos que satisfacen f'(x)=0 y:
# * f''(x)>0 es mínimo
# * f''(x)<0 es máximo
#
# Ejemplo:
# Vamos a calcular los máximos y los mínimos de la función f(x)=3x<sup>5</sup>-50x<sup>3</sup>+135x en el dominio [-5,5]

# %%
# Out:
# [-3, -1, 1, 3]

# %%
# Out:
# 60*x**3 + 300*x

# %%
#Otra forma de calcular la segunda derivada
# Out:
# 60*x*(x**2 + 5)

# %% [markdown]
# Así no podemos evaluar los puntos en la segunda derivada. Para ello necesitamos crear etiquetas:

# %%
# Out:
# -2520.00000000000

# %%
# Out:
# -360.000000000000

# %%
# Out:
# 360.000000000000

# %%
# Out:
# 2520.00000000000

# %% [markdown]
# Con esto, de hecho, podríamos calcular los máximos y los mínimos relativos, ¿no?
# ¡¡¡Cuidado!!! Nos faltaría saber que ocurre en los "bordes" del dominio.

# %%
# Out:
# -9000.00000000000

# %%
# Out:
# 9000.00000000000

# %% [markdown]
# Ahora que ya sabemos dónde están posicionados en el eje X los máximos y mínimos y si son máximo o mínimo, nos faltaría saber qué punto exacto son. Además, así podríamos sacar cuál es el máximo y el mínimo absoluto de la función dada.

# %%
# Out:
# 216.000000000000

# %%
# Out:
# -88.0000000000000

# %%
# Out:
# 88.0000000000000

# %%
# Out:
# -216.000000000000

# %%
# Out:
# -3800.00000000000

# %%
# Out:
# 3800.00000000000

# %% [markdown]
# Antes de continuar, vamos a introducir un ejemplo típico.
#
# Ejemplo: Projectile Motion.
# Queremos descubrir el ángulo de proyección para el que una pelota cubrirá la distancia horizontal máxima.
#
# <img src="Images/projectile.png" style="width: 500px;"/>
#
# En la figura, la pelota es lanzada desde el punto O y aterriza en el punto B, siendo la máxima altura el punto A.
# Cuando lanzamos la pelota, ésta tiene una velocidad inicial y la dirección de la velocidad provoca un determinado ángulo con el suelo.
# Llamemos **v** al vector velocidad inicial y al ámngulo que forma con la horizontal $\theta$.
# El vector velocidad puede ser descompuesto en sus dos componentes:
#
# > v<sub>x</sub>=v$\cdot$cos$\theta$
# > v<sub>y</sub>=v$\cdot$sen$\theta$
#
#  Cuando la pelota se mueve, su velocidad va cambiando. Llamémosla **u**.
# Para simplificar, asumiremos que la compomnente horizontal de **v**no varía durante el movimiento, mientfras que la componente verical decrece debido a la fuerza de la gravedad:
#
# > u<sub>x</sub>=v<sub>x</sub>
# > u<sub>y</sub>=v$\cdot$sen$\theta$-g$\cdot$t
#
# Como la componente horizontal de la velocidad se mantiene constante, mientras que la componente vertical va cmabiando en función del tiempo, las componentes de la distancia recorrida quedarían:
#
# > S<sub>x</sub>=v$\cdot$cos$\theta\cdot$t
# > S<sub>y</sub>=v$\cdot$sen$\theta\cdot$t-$\frac{1}{2}\cdot$g$\cdot$t<sup>2</sup>
#
# En otras palabras, S<sub>x</sub> y S<sub>y</sub> nos dan las coordenadas de la pelota en cualquier instante durante el vuelo.
# Como nota, el tiempo es en segundos, la velocidad en m/s, $\theta$ en grados y la gravedad en m/s<sup>2</sup>.
#
# Lo primero que nos preguntamos: ¿Cuánto tiempo tardará la pelota en caer al suelo desde que se encuentra en el punto más alto?
# Esto ocurrirá cuando u<sub>y</sub>=v$\cdot$sen$\theta$-g$\cdot$t=0
# De aquí podemos sacar que el cálculo de t se puede obtener:
# > t<sub>pico</sub>=$\frac{u \cdot sen\theta}{g}$
#
# Por lo que el tiempo de vuelo vendrá dado por:
# > t<sub>vuelo</sub>=2*t<sub>pico</sub>=$2 \cdot \frac{u \cdot sen\theta}{g}$
#
# Ejemplo:
# Calcula el tiempo de vuelo de una pelota que es lanzada con una velocidad inicial de 5 m/s con un ángulo de 45º.

# %%
# Out:
# 0.7215375318230076
